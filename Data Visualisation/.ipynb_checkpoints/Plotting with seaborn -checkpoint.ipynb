# %%
import pandas as pd 
reviews = pd.read_csv('winemag-data_first150k.csv', index_col=0)
% matplotlib inline
import seaborn as sns

# %%
sns.countplot(reviews['points'])

# %%
sns.kdeplot(reviews.query('price < 200').price)

# %%
reviews[reviews['price'] < 200]['price'].value_counts().sort_index().plot.line()

# %%
sns.kdeplot(reviews[reviews['price'] < 200].loc[:, ['price', 'points']].dropna().sample(5000))
# Out:
# C:\Users\Anirudh\Miniconda3\lib\site-packages\seaborn\distributions.py:645: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.distplot(reviews['points'], bins=10, kde=False)

# %%
sns.jointplot(x='Price',y='points',data=reviews[reviews['price'] < 100])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d395f5dedfc8> in <module>()
# ----> 1 sns.jointplot(x='Price',y='points',data=reviews[reviews['price'] < 100])
#
# ~\Miniconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2239     grid = JointGrid(x, y, data, dropna=dropna,
#    2240                      size=size, ratio=ratio, space=space,
# -> 2241                      xlim=xlim, ylim=ylim)
#    2242
#    2243     # Plot the data using the grid
#
# ~\Miniconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1681             if isinstance(var, string_types):
#    1682                 err = "Could not interpret input '{}'".format(var)
# -> 1683                 raise ValueError(err)
#    1684
#    1685         # Possibly drop NA
#
# ValueError: Could not interpret input 'Price'

# %%
sns.jointplot(x='price', y='points', data=reviews[reviews['price'] < 100], kind='hex',
                                                 gridsize=20)

# %%
df = reviews[reviews.variety.isin(reviews.variety.value_counts().
                                 head(5).index)]
sns.boxplot(x='variety',
           y='points',
           data=df)
